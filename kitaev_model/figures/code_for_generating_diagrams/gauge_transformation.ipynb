# %%
import numpy as np
import matplotlib.pyplot as plt
from koala.example_graphs import honeycomb_lattice
from koala import plotting as kplt

# %%
lattice, coloring = honeycomb_lattice(10,True)
fig, ax = plt.subplots(1,1,figsize=(5,5))
ujk = np.ones(lattice.n_edges)
kplt.plot_edges(lattice, directions=ujk)
plt.savefig('lattice_dirs.pdf')
